# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hazard_df = pd.read_csv("/content/drive/MyDrive/Property Hazard Problem/Hazard_train.csv")

# %%
hazard_df
# Out:
#           Id  Hazard  T1_V1  T1_V2  T1_V3  ... T2_V11 T2_V12 T2_V13 T2_V14 T2_V15
# 0      83642       2     10     23      4  ...      Y      N      E      2      1
# 1      92530       6      3     18      2  ...      Y      N      C      3      3
# 2      86131       4      5     20      4  ...      Y      N      D      1      1
# 3      88666       1      4      7      5  ...      Y      N      D      2      1
# 4      11122      21     10     21      6  ...      N      N      D      5      5
# ...      ...     ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 40794  88951       1     10      4      3  ...      Y      N      C      4      2
# 40795  60262       4      6      7      1  ...      Y      N      E      4      1
# 40796  13464       4      5      7      5  ...      Y      Y      E      1      5
# 40797  70407       1      1      9      2  ...      Y      N      D      1      1
# ...

# %%
hazard
